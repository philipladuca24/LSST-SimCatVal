# %%
#getting the background average as a function of exposure time, exposure time should be quantized based on number of exposured stacked

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization import ZScaleInterval, LinearStretch, ImageNormalize
import skyproj
from lsst.daf.butler import Butler

# %%
#do I have to use the RSP? is there a remote api?

# %%
butler = Butler("dp1", collections="LSSTComCam/DP1")
assert butler is not None
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /hildafs/projects/phy200017p/pladuca/miniforge3/envs/LSST/share/eups/Linux64/daf_butler/g8544ada454+ca6e99cc5e/python/lsst/daf/butler/_butler_config.py:138, in ButlerConfig.__init__(self, other, searchPaths, without_datastore)
#     137 try:
# --> 138     butlerConfig = Config(other)
#     139 except FileNotFoundError as e:
#     140     # No reason to talk about aliases unless we were given a
#     141     # string and the alias was not resolved.
#
# File /hildafs/projects/phy200017p/pladuca/miniforge3/envs/LSST/share/eups/Linux64/daf_butler/g8544ada454+ca6e99cc5e/python/lsst/daf/butler/_config.py:287, in Config.__init__(self, other)
#     285 elif isinstance(other, str | ResourcePath | Path):
#     286     # if other is a string, assume it is a file path/URI
# --> 287     self.__initFromUri(other)
#     288     self._processExplicitIncludes()
#
# File /hildafs/projects/phy200017p/pladuca/miniforge3/envs/LSST/share/eups/Linux64/daf_butler/g8544ada454+ca6e99cc5e/python/lsst/daf/butler/_config.py:393, in Config.__initFromUri(self, path)
#     392 if not uri.exists():
# --> 393     raise FileNotFoundError(f"Config location {uri} does not exist.")
#     394 raise RuntimeError(f"The Config URI does not have a supported extension: {uri}")
#
# FileNotFoundError: Config location file:///hildafs/projects/phy200017p/pladuca/lsst-sim-package/LSST-SimCatVal/LSST-SimCatVal/dp1 does not exist.
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 butler = Butler("dp1", collections="LSSTComCam/DP1")
#       2 assert butler is not None
#
# File /hildafs/projects/phy200017p/pladuca/miniforge3/envs/LSST/share/eups/Linux64/daf_butler/g8544ada454+ca6e99cc5e/python/lsst/daf/butler/_butler.py:160, in Butler.__new__(cls, config, collections, run, searchPaths, writeable, inferDefaults, without_datastore, **kwargs)
#     147 def __new__(
#     148     cls,
#     149     config: Config | ResourcePathExpression | None = None,
#    (...)    157     **kwargs: Any,
#     158 ) -> Butler:
#     159     if cls is Butler:
# --> 160         return Butler.from_config(
#     161             config=config,
#     162             collections=collections,
#     163             run=run,
#     164             searchPaths=searchPaths,
#     165             writeable=writeable,
#     166             inferDefaults=inferDefaults,
#     167             without_datastore=without_datastore,
#     168             **kwargs,
#     169         )
#     171     # Note: we do not pass any parameters to __new__, Python will pass them
#     172     # to __init__ after __new__ returns sub-class instance.
#     173     return super().__new__(cls)
#
# File /hildafs/projects/phy200017p/pladuca/miniforge3/envs/LSST/share/eups/Linux64/daf_butler/g8544ada454+ca6e99cc5e/python/lsst/daf/butler/_butler.py:318, in Butler.from_config(cls, config, collections, run, searchPaths, writeable, inferDefaults, without_datastore, **kwargs)
#     312 options = ButlerInstanceOptions(
#     313     collections=collections, run=run, writeable=writeable, inferDefaults=inferDefaults, kwargs=kwargs
#     314 )
#     316 # Load the Butler configuration.  This may involve searching the
#     317 # environment to locate a configuration file.
# --> 318 butler_config = ButlerConfig(config, searchPaths=searchPaths, without_datastore=without_datastore)
#     319 butler_type = butler_config.get_butler_type()
#     321 # Make DirectButler if class is not specified.
#
# File /hildafs/projects/phy200017p/pladuca/miniforge3/envs/LSST/share/eups/Linux64/daf_butler/g8544ada454+ca6e99cc5e/python/lsst/daf/butler/_butler_config.py:159, in ButlerConfig.__init__(self, other, searchPaths, without_datastore)
#     157     else:
#     158         errmsg = str(e)
# --> 159     raise FileNotFoundError(errmsg) from e
#     161 configFile = butlerConfig.configFile
#     162 if configFile is not None:
#
# FileNotFoundError: Config location file:///hildafs/projects/phy200017p/pladuca/lsst-sim-package/LSST-SimCatVal/LSST-SimCatVal/dp1 does not exist. (given 'dp1' and no known aliases: No repository index defined.  Neither of the environment variables DAF_BUTLER_REPOSITORIES or DAF_BUTLER_REPOSITORY_INDEX was set.)
